# %% [markdown]
# # Unified X Frozen Candidate454 MLP
#
# Frozen inference only. Candidate454 is constructed online from the permitted bar1m and financial inputs; the stock-pool source is used only for output keys. Frozen weights are stored in a Python companion module for platform upload compatibility.
#
# Canonical entrypoint: `unified_x.py`. Upload this notebook together with its same-directory Python dependencies.

# %%
from unified_x import main
