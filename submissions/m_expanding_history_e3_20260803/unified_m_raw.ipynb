# %% [markdown]
# # M Expanding History E3 Candidate
#
# Frozen 2019-2024 expanding-history raw L1-L3 microstructure candidate. Local proxy evidence only; AIStudio and platform validation pending.
#
# Canonical entrypoint: `unified_m_raw.py`. Upload this notebook together with its same-directory Python dependencies.

# %%
from unified_m_raw import main
