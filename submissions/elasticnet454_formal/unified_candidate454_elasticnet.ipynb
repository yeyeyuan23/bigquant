# %% [markdown]
# # Candidate454 Rolling ElasticNet — Formal Submission
#
# This is the formal causal submission entrypoint, not a score probe. It reconstructs the frozen 454-factor universe from `bar1m` and `financial`, trains on the previous 60 trading dates, leaves one trading date for label isolation, and predicts the next block of up to 20 trading dates.
#
# Canonical entrypoint: `unified_candidate454_elasticnet.py`. Upload this notebook together with `unified_candidate454_elasticnet.py`, `unified_candidate454_spec.py`, `unified_candidate454_components.py`, `unified_candidate454_direct.py`, and `unified_candidate454_gtja.py`.

# %%
from unified_candidate454_elasticnet import main
