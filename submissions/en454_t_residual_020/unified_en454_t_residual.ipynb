# %% [markdown]
# # Candidate454 ElasticNet + Residual T (20%)
# Formal AIStudio submission. Upload this notebook with its three sibling Python modules.

# %%
from unified_en454_t_residual import main
