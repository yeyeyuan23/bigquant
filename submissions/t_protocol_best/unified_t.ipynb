# %% [markdown]
# # Frozen original Temporal-deep expert
# Upload this notebook with its three sibling Python modules.

# %%
from unified_t import main
